# %% [markdown]
# # 強化学習用のモジュールインポート

# %%
from baby_steps_of_rl_ja_master.FN import fn_framework

# %%
from baby_steps_of_rl_ja_master.FN import value_function_agent

# %%
from baby_steps_of_rl_ja_master.FN import dqn_agent

# %%
from baby_steps_of_rl_ja_master.FN import policy_gradient_agent

# %%
from baby_steps_of_rl_ja_master.FN import a2c_agent

# %%
### GPUを指定
import tensorflow as tf
tf.debugging.set_log_device_placement(True)

# %% [markdown]
# <br><br>

# %% [markdown]
# # gymに収録されているゲームの種類

# %% [markdown]
# https://github.com/openai/gym/blob/master/gym/envs/__init__.py
#
# _____cartpole-v0と-v1の違いは以下の通り<br>
# <br>
# register(<br>
#     id="CartPole-v0",<br>
#     entry_point="gym.envs.classic_control.cartpole:CartPoleEnv",<br>
#     max_episode_steps=200,<br>
#     reward_threshold=195.0,<br>
# )<br>
#
# register(<br>
#     id="CartPole-v1",<br>
#     entry_point="gym.envs.classic_control.cartpole:CartPoleEnv",<br>
#     max_episode_steps=500,<br>
#     reward_threshold=475.0,<br>
# )<br>

# %% [markdown]
# <br><br>

# %% [markdown]
# # value_function_agentを活用したシンプルなNNの強化学習

# %% [markdown]
# ## episode=220 初期値

# %%
value_function_agent.main(False) #学習
# Out:
# /Users/ta2bonn/miniforge3/envs/ds_env/lib/python3.9/site-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# At episode 10, reward is 27.1 (+/-8.055)
# At episode 20, reward is 17.0 (+/-6.723)
# At episode 30, reward is 24.4 (+/-8.969)
# At episode 40, reward is 20.6 (+/-8.913)
# Done initialization. From now, begin training!
# At episode 50, reward is 15.9 (+/-16.784)
# At episode 60, reward is 10.7 (+/-1.676)
# At episode 70, reward is 10.5 (+/-1.285)
# At episode 80, reward is 9.6 (+/-0.663)
# At episode 90, reward is 9.4 (+/-0.8)
# At episode 100, reward is 9.9 (+/-1.136)
# At episode 110, reward is 11.3 (+/-2.1)
# At episode 120, reward is 17.4 (+/-6.437)
# At episode 130, reward is 64.2 (+/-53.156)
# At episode 140, reward is 116.7 (+/-51.965)
# At episode 150, reward is 125.3 (+/-69.361)
# ...

# %%
value_function_agent.main(True)
# Out:
# /Users/ta2bonn/miniforge3/envs/ds_env/lib/python3.9/site-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# Get reward 144.0.
# Get reward 144.0.
# Get reward 141.0.
# Get reward 143.0.
# Get reward 138.0.

# %% [markdown]
# <br>

# %% [markdown]
# ## episode=1000

# %%
value_function_agent.main(play = False) #学習
# Out:
# At episode 10, reward is 20.1 (+/-8.619)
# At episode 20, reward is 31.9 (+/-13.179)
# At episode 30, reward is 16.2 (+/-5.758)
# Done initialization. From now, begin training!
# At episode 40, reward is 34.2 (+/-16.946)
# At episode 50, reward is 10.7 (+/-1.552)
# At episode 60, reward is 10.1 (+/-0.7)
# At episode 70, reward is 9.5 (+/-0.806)
# At episode 80, reward is 9.1 (+/-0.831)
# At episode 90, reward is 9.7 (+/-1.1)
# At episode 100, reward is 10.1 (+/-0.943)
# At episode 110, reward is 19.4 (+/-11.28)
# At episode 120, reward is 55.8 (+/-28.694)
# At episode 130, reward is 129.6 (+/-36.93)
# At episode 140, reward is 152.8 (+/-40.069)
# At episode 150, reward is 188.3 (+/-56.285)
# At episode 160, reward is 329.4 (+/-154.157)
# At episode 170, reward is 220.3 (+/-134.478)
# At episode 180, reward is 196.2 (+/-67.459)
# At episode 190, reward is 253.3 (+/-99.679)
# At episode 200, reward is 170.5 (+/-95.643)
# At episode 210, reward is 135.1 (+/-51.04)
# ...

# %%
value_function_agent.main(play = True)
# Out:
# Get reward 112.0.
# Get reward 110.0.
# Get reward 110.0.
# Get reward 108.0.
# Get reward 108.0.

# %% [markdown]
# <br>

# %% [markdown]
# # dqn_agentを活用した強化学習

# %%
dqn_agent.main(play = False, is_test = True)
# Out:
# Train on test mode
# At episode 10, reward is 27.8 (+/-13.333)
# At episode 20, reward is 16.9 (+/-3.807)
# At episode 30, reward is 19.2 (+/-9.152)
# At episode 40, reward is 25.3 (+/-16.983)
# At episode 50, reward is 26.8 (+/-8.577)
# At episode 60, reward is 22.8 (+/-8.761)
# At episode 70, reward is 20.3 (+/-7.497)
# At episode 80, reward is 20.8 (+/-7.359)
# At episode 90, reward is 22.4 (+/-12.387)
# At episode 100, reward is 21.1 (+/-10.387)
# At episode 110, reward is 23.2 (+/-11.652)
# At episode 120, reward is 20.6 (+/-14.354)
# At episode 130, reward is 17.8 (+/-4.445)
# At episode 140, reward is 22.2 (+/-13.37)
# At episode 150, reward is 17.7 (+/-6.768)
# At episode 160, reward is 24.2 (+/-10.515)
# At episode 170, reward is 22.4 (+/-7.338)
# At episode 180, reward is 20.3 (+/-8.844)
# At episode 190, reward is 23.5 (+/-14.78)
# At episode 200, reward is 31.4 (+/-17.761)
# Done initialization. From now, begin training!
# Metal device set to: Apple M1 Pro
# ...

# %%
dqn_agent.main(play = True, is_test = True)
# Out:
# Train on test mode
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: METAL, pci bus id: <undefined>
#
# alhost/replica:0/task:0/device:GPU:0
# dense_2/bias/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/bias/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/bias/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# dense_2/Softmax: (Softmax): /job:localhost/replica:0/task:0/device:GPU:0
# AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %% [markdown]
# <br><br>

# %% [markdown]
# # policy_gradient_agentを活用した強化学習

# %%
policy_gradient_agent.main(play = False)
# Out:
# At episode 10, reward is 22.7 (+/-8.521)
# Done initialization. From now, begin training!
# Metal device set to: Apple M1 Pro
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: METAL, pci bus id: <undefined>
#
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
#
# dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Initializer/random_uniform: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %%
policy_gradient_agent.main(play = True)
# Out:
# Metal device set to: Apple M1 Pro
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: METAL, pci bus id: <undefined>
#
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2022-05-28 14:13:25.820055: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-28 14:13:25.820374: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-05-28 14:13:25.829398: I tensorflow/core/common_runtime/placer.cc:114] dense/kernel/Initializer/random_uniform/RandomUniform: (RandomUniform): /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # a2c_agentを活用した強化学習

# %%
a2c_agent.main(play = False, is_test = True)
# Out:
# Train on test mode
# Done initialization. From now, begin training!
# /Users/ta2bonn/miniforge3/envs/ds_env/lib/python3.9/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Metal device set to: Apple M1 Pro
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: METAL, pci bus id: <undefined>
# /Users/ta2bonn/miniforge3/envs/ds_env/lib/python3.9/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2022-05-15 11:51:40.243659: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
a2c_agent.main(play = True, is_test = True)
# Out:
# Train on test mode
# arIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/kernel/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/bias/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# dense/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# dense/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# # ニューラルネットワーク実装　+++ 不要 +++

# %%
import numpy as np
from tensorflow.python import keras as K

model = K.Sequential([
    K.layers.Dense(units=4, input_shape=((2, ))),
])

weight, bias = model.layers[0].get_weights()
print("Weight shape is {}.".format(weight.shape))
print("Bias shape is {}.".format(bias.shape))

x = np.random.rand(1, 2)
y = model.predict(x)
print("x is ({}) and y is ({}).".format(x.shape, y.shape))
# Out:
# Metal device set to: Apple M1 Pro
# Weight shape is (2, 4).
# Bias shape is (4,).
# x is ((1, 2)) and y is ((1, 4)).
# 2022-05-14 11:37:54.106059: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-14 11:37:54.106196: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2022-05-14 11:37:54.157043: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-14 11:37:54.181925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
import numpy as np
from tensorflow.python import keras as K

# 2-layer neural network.
model = K.Sequential([
    K.layers.Dense(units=4, input_shape=((2, )),
                   activation="sigmoid"),
    K.layers.Dense(units=4),
])

# Make batch size = 3 data (dimension of x is 2).
batch = np.random.rand(3, 2)

y = model.predict(batch)
print(y.shape)  # Will be (3, 4)
# Out:
# (3, 4)
# 2022-05-14 11:37:54.227836: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.python import keras as K
import tensorflow as tf


dataset = load_boston()

y = dataset.target
X = dataset.data

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33)

model = K.Sequential([
    tf.keras.layers.BatchNormalization(input_shape=(13,)),
    K.layers.Dense(units=13, activation="softplus", kernel_regularizer="l1"),
    K.layers.Dense(units=1)
])
model.compile(loss="mean_squared_error", optimizer="sgd")
model.fit(X_train, y_train, epochs=8)

predicts = model.predict(X_test)

result = pd.DataFrame({
    "predict": np.reshape(predicts, (-1,)),
    "actual": y_test
})
limit = np.max(y_test)

result.plot.scatter(x="actual", y="predict", xlim=(0, limit), ylim=(0, limit))
plt.show()
# Out:
# /Users/ta2bonn/miniforge3/envs/ds_env/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
   
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
from sklearn.metrics import classification_report
from tensorflow.python import keras as K
import tensorflow as tf

dataset = load_digits()
image_shape = (8, 8, 1)
num_class = 10

y = dataset.target
y = tf.keras.utils.to_categorical(y, num_class)
X = dataset.data
X = np.array([data.reshape(image_shape) for data in X])

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33)

model = K.Sequential([
    K.layers.Conv2D(
        5, kernel_size=3, strides=1, padding="same",
        input_shape=image_shape, activation="relu"),
    K.layers.Conv2D(
        3, kernel_size=2, strides=1, padding="same",
        activation="relu"),
    K.layers.Flatten(),
    K.layers.Dense(units=num_class, activation="softmax")
])
model.compile(loss="categorical_crossentropy", optimizer="sgd")
model.fit(X_train, y_train, epochs=8)

predicts = model.predict(X_test)
predicts = np.argmax(predicts, axis=1)
actual = np.argmax(y_test, axis=1)
print(classification_report(actual, predicts))
# Out:
# Epoch 1/8
# 23/38 [=================>............] - ETA: 0s - loss: 2.3127
# 2022-05-14 11:37:55.785524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 38/38 [==============================] - 0s 5ms/step - loss: 2.2523
# Epoch 2/8
# 38/38 [==============================] - 0s 5ms/step - loss: 1.8866
# Epoch 3/8
# 38/38 [==============================] - 0s 5ms/step - loss: 1.2185
# Epoch 4/8
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6937
# Epoch 5/8
# 38/38 [==============================] - 0s 5ms/step - loss: 0.4540
# Epoch 6/8
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3253
# Epoch 7/8
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2667
# Epoch 8/8
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2302
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        68
# ...

# %% [markdown]
# <br><br>
